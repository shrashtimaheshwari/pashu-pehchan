# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from tensorflow.keras import layers, Model
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input

# %%
DATASET_PATH = "dataset_final_pp_cropped"
IMG_SIZE = 300
BATCH_SIZE = 16
EPOCHS_STAGE1 = 30
EPOCHS_STAGE2 = 30

data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomContrast(0.1),
])

# %%
# =========================
# BUILD LABEL MAPS
# =========================

species_map = {"cow": 0, "buffalo": 1}
group_map = {}
breed_map = {}

image_paths = []
species_labels = []
group_labels = []
breed_labels = []

group_index = 0
breed_index = 0

for species in os.listdir(DATASET_PATH):
    if species.startswith("."):
        continue

    species_path = os.path.join(DATASET_PATH, species)

    if species == "cow":
        for group in os.listdir(species_path):
            if group.startswith("."):
                continue

            group_path = os.path.join(species_path, group)

            if group not in group_map:
                group_map[group] = group_index
                group_index += 1

            for breed in os.listdir(group_path):
                if breed.startswith("."):
                    continue

                breed_path = os.path.join(group_path, breed)

                if breed not in breed_map:
                    breed_map[breed] = breed_index
                    breed_index += 1

                for file in os.listdir(breed_path):
                    if file.lower().endswith((".jpg", ".jpeg", ".png")):
                        image_paths.append(os.path.join(breed_path, file))
                        species_labels.append(species_map["cow"])
                        group_labels.append(group_map[group])
                        breed_labels.append(breed_map[breed])

    elif species == "buffalo":

        if "buffalo" not in group_map:
            group_map["buffalo"] = group_index
            group_index += 1

        for breed in os.listdir(species_path):
            if breed.startswith("."):
                continue

            breed_path = os.path.join(species_path, breed)

            if breed not in breed_map:
                breed_map[breed] = breed_index
                breed_index += 1

            for file in os.listdir(breed_path):
                if file.lower().endswith((".jpg", ".jpeg", ".png")):
                    image_paths.append(os.path.join(breed_path, file))
                    species_labels.append(species_map["buffalo"])
                    group_labels.append(group_map["buffalo"])
                    breed_labels.append(breed_map[breed])

# %%
image_paths = np.array(image_paths)
species_labels = np.array(species_labels)
group_labels = np.array(group_labels)
breed_labels = np.array(breed_labels)

NUM_GROUPS = len(group_map)
NUM_BREEDS = len(breed_map)
breed_names = list(breed_map.keys())

# %%
# =========================
# TRAIN/VAL SPLIT
# =========================

train_paths, val_paths, \
train_species, val_species, \
train_group, val_group, \
train_breed, val_breed = train_test_split(
    image_paths,
    species_labels,
    group_labels,
    breed_labels,
    test_size=0.2,
    random_state=42,
    stratify=breed_labels
)

# %%
# =========================
# DATA PIPELINE
# =========================

def load_image(path, augment=False):

    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (IMG_SIZE, IMG_SIZE))

    if augment:
        img = data_augmentation(img)

    img = preprocess_input(img)

    return img

def create_dataset(paths, species, group, breed, augment=False):

    ds = tf.data.Dataset.from_tensor_slices((paths, species, group, breed))

    def process(path, sp, gr, br):
        img = load_image(path, augment)
        return img, {
            "species": sp,
            "group": gr,
            "breed": br
        }

    ds = ds.map(process, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds

train_ds = create_dataset(train_paths, train_species, train_group, train_breed, augment=True)
val_ds = create_dataset(val_paths, val_species, val_group, val_breed, augment=False)

# %%
# =========================
# MODEL
# =========================

base_model = EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_breed_accuracy",
    patience=6,
    restore_best_weights=True,
    mode="max"
)
base_model.trainable = False

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)

species_out = layers.Dense(2, activation="softmax", name="species")(x)
group_out = layers.Dense(NUM_GROUPS, activation="softmax", name="group")(x)
breed_out = layers.Dense(NUM_BREEDS, activation="softmax", name="breed")(x)

model = Model(inputs=inputs, outputs=[species_out, group_out, breed_out])


model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss={
        "species": "sparse_categorical_crossentropy",
        "group": "sparse_categorical_crossentropy",
        "breed": "sparse_categorical_crossentropy"
    },
    loss_weights={
        "species": 0.3,
        "group": 0.7,
        "breed": 3.0
    },
    metrics={
        "species": "accuracy",
        "group": "accuracy",
        "breed": "accuracy"
    }
)

# %%
# =========================
# STAGE 1 TRAINING
# =========================

history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_STAGE1,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 109s 438ms/step - breed_accuracy: 0.0285 - breed_loss: 3.5478 - group_accuracy: 0.1358 - group_loss: 1.9092 - loss: 12.2671 - species_accuracy: 0.2799 - species_loss: 0.9570 - val_breed_accuracy: 0.0551 - val_breed_loss: 3.4426 - val_group_accuracy: 0.1721 - val_group_loss: 1.8026 - val_loss: 11.8039 - val_species_accuracy: 0.5073 - val_species_loss: 0.7143
# Epoch 2/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 91s 406ms/step - breed_accuracy: 0.0487 - breed_loss: 3.4646 - group_accuracy: 0.1992 - group_loss: 1.7949 - loss: 11.8477 - species_accuracy: 0.6004 - species_loss: 0.6578 - val_breed_accuracy: 0.0754 - val_breed_loss: 3.3758 - val_group_accuracy: 0.2407 - val_group_loss: 1.7141 - val_loss: 11.4888 - val_species_accuracy: 0.8065 - val_species_loss: 0.5382
# Epoch 3/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 91s 407ms/step - breed_accuracy: 0.0544 - breed_loss: 3.4001 - group_accuracy: 0.2382 - group_loss: 1.7126 - loss: 11.5484 - species_accuracy: 0.8122 - species_loss: 0.4972 - val_breed_accuracy: 0.0956 - val_breed_loss: 3.3152 - val_group_accuracy: 0.3273 - val_group_loss: 1.6405 - val_loss: 11.2259 - val_species_accuracy: 0.8976 - val_species_loss: 0.4392
# Epoch 4/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 91s 407ms/step - breed_accuracy: 0.0835 - breed_loss: 3.3158 - group_accuracy: 0.3260 - group_loss: 1.6428 - loss: 11.2184 - species_accuracy: 0.8828 - species_loss: 0.4028 - val_breed_accuracy: 0.1204 - val_breed_loss: 3.2587 - val_group_accuracy: 0.3993 - val_group_loss: 1.5752 - val_loss: 10.9934 - val_species_accuracy: 0.9111 - val_species_loss: 0.3806
# Epoch 5/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 102s 455ms/step - breed_accuracy: 0.3630 - breed_loss: 2.4014 - group_accuracy: 0.7421 - group_loss: 0.8556 - loss: 7.8528 - species_accuracy: 0.9287 - species_loss: 0.1655 - val_breed_accuracy: 0.3543 - val_breed_loss: 2.4140 - val_group_accuracy: 0.7717 - val_group_loss: 0.8368 - val_loss: 7.8749 - val_species_accuracy: 0.9539 - val_species_loss: 0.1489
# Epoch 29/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 98s 441ms/step - breed_accuracy: 0.3461 - breed_loss: 2.4043 - group_accuracy: 0.7447 - group_loss: 0.8516 - loss: 7.8572 - species_accuracy: 0.9370 - species_loss: 0.1608 - val_breed_accuracy: 0.3600 - val_breed_loss: 2.3909 - val_group_accuracy: 0.7762 - val_group_loss: 0.8226 - val_loss: 7.7947 - val_species_accuracy: 0.9573 - val_species_loss: 0.1457
# Epoch 30/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 97s 436ms/step - breed_accuracy: 0.3642 - breed_loss: 2.3475 - group_accuracy: 0.7516 - group_loss: 0.8219 - loss: 7.6653 - species_accuracy: 0.9337 - species_loss: 0.1582 - val_breed_accuracy: 0.3600 - val_breed_loss: 2.3684 - val_group_accuracy: 0.7784 - val_group_loss: 0.8089 - val_loss: 7.7169 - val_species_accuracy: 0.9618 - val_species_loss: 0.1431

# %%
# =========================
# STAGE 2 FINE-TUNING
# =========================

base_model.trainable = True

for layer in base_model.layers[:-30]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss={
        "species": "sparse_categorical_crossentropy",
        "group": "sparse_categorical_crossentropy",
        "breed": "sparse_categorical_crossentropy"
    },
    loss_weights={
        "species": 0.3,
        "group": 0.7,
        "breed": 3.0
    },
    metrics={
        "species": "accuracy",
        "group": "accuracy",
        "breed": "accuracy"
    }
)

history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_STAGE2,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 139s 544ms/step - breed_accuracy: 0.2904 - breed_loss: 2.7802 - group_accuracy: 0.6441 - group_loss: 1.2117 - loss: 9.3185 - species_accuracy: 0.8363 - species_loss: 0.4324 - val_breed_accuracy: 0.4196 - val_breed_loss: 2.3279 - val_group_accuracy: 0.8234 - val_group_loss: 0.8074 - val_loss: 7.6304 - val_species_accuracy: 0.9269 - val_species_loss: 0.2529
# Epoch 2/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 114s 513ms/step - breed_accuracy: 0.3599 - breed_loss: 2.5493 - group_accuracy: 0.7218 - group_loss: 1.0268 - loss: 8.4597 - species_accuracy: 0.8955 - species_loss: 0.3108 - val_breed_accuracy: 0.4207 - val_breed_loss: 2.2015 - val_group_accuracy: 0.8403 - val_group_loss: 0.7268 - val_loss: 7.1886 - val_species_accuracy: 0.9280 - val_species_loss: 0.2322
# Epoch 3/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 118s 530ms/step - breed_accuracy: 0.3969 - breed_loss: 2.3511 - group_accuracy: 0.7544 - group_loss: 0.8770 - loss: 7.7422 - species_accuracy: 0.9116 - species_loss: 0.2504 - val_breed_accuracy: 0.4387 - val_breed_loss: 2.0600 - val_group_accuracy: 0.8403 - val_group_loss: 0.6473 - val_loss: 6.6987 - val_species_accuracy: 0.9314 - val_species_loss: 0.2016
# Epoch 4/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 189s 846ms/step - breed_accuracy: 0.6418 - breed_loss: 1.2118 - group_accuracy: 0.8655 - group_loss: 0.4424 - loss: 3.9700 - species_accuracy: 0.9706 - species_loss: 0.0835 - val_breed_accuracy: 0.6333 - val_breed_loss: 1.1598 - val_group_accuracy: 0.8909 - val_group_loss: 0.3661 - val_loss: 3.7599 - val_species_accuracy: 0.9798 - val_species_loss: 0.0735
# Epoch 27/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 130s 581ms/step - breed_accuracy: 0.6538 - breed_loss: 1.1938 - group_accuracy: 0.8587 - group_loss: 0.4423 - loss: 3.9162 - species_accuracy: 0.9608 - species_loss: 0.0840 - val_breed_accuracy: 0.6378 - val_breed_loss: 1.1454 - val_group_accuracy: 0.8886 - val_group_loss: 0.3627 - val_loss: 3.7134 - val_species_accuracy: 0.9798 - val_species_loss: 0.0707
# Epoch 28/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 108s 482ms/step - breed_accuracy: 0.6536 - breed_loss: 1.1792 - group_accuracy: 0.8653 - group_loss: 0.4337 - loss: 3.8649 - species_accuracy: 0.9754 - species_loss: 0.0798 - val_breed_accuracy: 0.6367 - val_breed_loss: 1.1344 - val_group_accuracy: 0.8909 - val_group_loss: 0.3598 - val_loss: 3.6778 - val_species_accuracy: 0.9809 - val_species_loss: 0.0689
# Epoch 29/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 106s 477ms/step - breed_accuracy: 0.6641 - breed_loss: 1.1646 - group_accuracy: 0.8563 - group_loss: 0.4403 - loss: 3.8258 - species_accuracy: 0.9699 - species_loss: 0.0799 - val_breed_accuracy: 0.6468 - val_breed_loss: 1.1229 - val_group_accuracy: 0.8875 - val_group_loss: 0.3575 - val_loss: 3.6414 - val_species_accuracy: 0.9809 - val_species_loss: 0.0686
# Epoch 30/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 107s 478ms/step - breed_accuracy: 0.6616 - breed_loss: 1.1405 - group_accuracy: 0.8654 - group_loss: 0.4247 - loss: 3.7421 - species_accuracy: 0.9704 - species_loss: 0.0785 - val_breed_accuracy: 0.6490 - val_breed_loss: 1.1114 - val_group_accuracy: 0.8909 - val_group_loss: 0.3554 - val_loss: 3.6051 - val_species_accuracy: 0.9820 - val_species_loss: 0.0674

# %%
# =========================
# PLOTS
# =========================

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history2.history["breed_accuracy"], label="Train Breed Acc")
plt.plot(history2.history["val_breed_accuracy"], label="Val Breed Acc")
plt.legend()
plt.title("Breed Accuracy")

plt.subplot(1,2,2)
plt.plot(history2.history["group_accuracy"], label="Train Group Acc")
plt.plot(history2.history["val_group_accuracy"], label="Val Group Acc")
plt.legend()
plt.title("Group Accuracy")

plt.show()

# %%
# =========================
# CONFUSION MATRIX
# =========================

y_true = []
y_pred = []

for images, labels in val_ds:
    preds = model.predict(images, verbose=0)
    breed_preds = np.argmax(preds[2], axis=1)

    y_pred.extend(breed_preds)
    y_true.extend(labels["breed"].numpy())

cm = confusion_matrix(
    y_true,
    y_pred,
    labels=list(range(NUM_BREEDS))
)

plt.figure(figsize=(14,14))
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=breed_names
)

disp.plot(xticks_rotation=90)
plt.title("Breed Confusion Matrix")
plt.show()

# %%
import json
import os

os.makedirs("backend_model", exist_ok=True)

model.save("backend_model/cattle_classifier.keras")

with open("backend_model/breed_names.json", "w", encoding="utf-8") as f:
    json.dump(breed_names, f, indent=4)
    
print("Saved model and breed names to backend_model/")
